# %%
import pandas as p
data=p.read_csv("C:\\Users\\Divya\\Desktop\\Syracuse University\\Sem 2\\Big Data Analytics\\Project\\initialDataset.csv")

# %%
data
# Out:
#                 tweet_id                                               text  \
# 0    1240728065983959040  #statewaterheaters #getitin #corona #keepingpe...
# 1    1240728187136610306  "ain't no humans outside! (corona!)" 😂😂😂🤣 @ Cl...
# 2    1240728221986906113  Salam Friends\nLooking at the grave financial ...
# 3    1240728361556750338  Thanks to COVID19 we are under unprecedented l...
# 4    1240728639358017536  #tbt to the current #anime that I'm rewatching...
# ..                   ...                                                ...
# 740  1242374749323440130  Locked down Germany, nary someone on streets o...
# 741  1242374760316764160  All this travelling might be the worst thing t...
# 742  1242375585642340352  Waiting for morning indoor exercise #tuesdaymo...
# 743  1242376079530172417  Quarantine Challenge \nTopic by - roshni_nc \n...
# 744  1242376399031320578  #longing for the day when this #corona virus #...
#
#                             place  polarity
# ...

# %%
tweets=data['text'].values

# %%
tweets
# Out:
# array(['#statewaterheaters #getitin #corona #keepingpeoplesafe #plumber #pickeringtonohio new water heater swap out @ Pickerington, Ohio https://t.co/fMcPtH88m4',
#        '"ain\'t no humans outside! (corona!)" 😂😂😂🤣 @ Cleveland, Ohio https://t.co/1i7cIsrITb',
#        'Salam Friends\nLooking at the grave financial situation of middle &amp; lower class household in Karachi developed due to Corona threat, we are planning to take some initiative.\nIdeas required… https://t.co/uC60hpxYDj',
#        'Thanks to COVID19 we are under unprecedented levels of stress. Thanks to corona, my Seanie was denied boarding in Paris before heading to Abidjan on 10-week contract. He unexpectedly… https://t.co/M1yzRvLftL',
#        "#tbt to the current #anime that I'm rewatching with the #corona threat keeping us home \n\n#codegeass #lelouchoftherebellion \nOn @netflix \n\n#theyze #Wolf #africa @ Africa https://t.co/5rdBOhrRSq",
# ...

# %%
# sklearn contains two vectorizers

# CountVectorizer can give you Boolean or TF vectors
# http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# TfidfVectorizer can give you TF or TFIDF vectors
# http://scikit-learn.org/stable/modul les/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# Read the sklearn documentation to understand all vectorization options

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# several commonly used vectorizer setting

#  unigram boolean vectorizer, set minimum document frequency to 5
unigram_bool_vectorizer = CountVectorizer(encoding='latin-1', binary=True, min_df=5, stop_words='english')

#  unigram term frequency vectorizer, set minimum document frequency to 5
unigram_count_vectorizer = CountVectorizer(encoding='latin-1', binary=False, min_df=5, stop_words='english')

#  unigram and bigram term frequency vectorizer, set minimum document frequency to 5
gram12_count_vectorizer = CountVectorizer(encoding='latin-1', ngram_range=(1,2), min_df=5, stop_words='english')

#  bigram term frequency vectorizer, set minimum document frequency to 5
gram22_count_vectorizer = CountVectorizer(encoding='latin-1', ngram_range=(2,2), min_df=5, stop_words='english')

#  unigram tfidf vectorizer, set minimum document frequency to 5
unigram_tfidf_vectorizer = TfidfVectorizer(encoding='latin-1', use_idf=True, min_df=5, stop_words='english')

#  boolean vectorizer, set minimum document frequency to 5
unigram_bool_vectorizer = CountVectorizer(encoding='latin-1', binary=True, min_df=5, stop_words='english')

# %%
StemmingCase, mergingRemoving,  stop wordsWord, clustering

# %%
# The vectorizer can do "fit" and "transform"
# fit is a process to collect unique tokens into the vocabulary
# transform is a process to convert each document to vector based on the vocabulary
# These two processes can be done together using fit_transform(), or used individually: fit() or transform()

# fit vocabulary in training documents and transform the training documents into vectors
X_train_vec = unigram_count_vectorizer.fit_transform(tweets)

# check the content of a document vector
print(X_train_vec.shape)
#print(X_train_vec[0].toarray())

# check the size of the constructed vocabulary
print(len(unigram_count_vectorizer.vocabulary_))

# print out the first 10 items in the vocabulary
print(list(unigram_count_vectorizer.vocabulary_.items())[:])

# check word index in vocabulary
print(unigram_count_vectorizer.vocabulary_.get('ordered'))
# Out:
# (745, 353)
# 353
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
s= ['👋 Welcome', '👋 Welcome']

v = TfidfVectorizer(token_pattern=r'[^\s]+')
v.fit(s)
v.get_feature_names()
# Out:
# ['welcome', '👋']

# %%
x
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=1, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=False, token_pattern='[^\\s]+', tokenizer=None,
#                 use_idf=True, vocabulary=None)

# %%
# fit vocabulary in training documents and transform the training documents into vectors
X_train_vect = gram22_count_vectorizer.fit_transform(tweets)

# check the content of a document vector
print(X_train_vect.shape)
#print(X_train_vect[0].toarray())

# check the size of the constructed vocabulary
#print(len(unigram_tfidf_vectorizer.vocabulary_))

# print out the first 10 items in the vocabulary
print(list(gram22_count_vectorizer.vocabulary_.items())[:])

# check word index in vocabulary
print(gram22_count_vectorizer.vocabulary_.get('ordered'))
# Out:
# (745, 91)
# ...

# %%
# fit vocabulary in training documents and transform the training documents into vectors
X_train_vect = unigram_tfidf_vectorizer.fit_transform(tweets)

# check the content of a document vector
print(X_train_vect.shape)
#print(X_train_vect[0].toarray())

# check the size of the constructed vocabulary
print(len(unigram_tfidf_vectorizer.vocabulary_))

# print out the first 10 items in the vocabulary
print(list(unigram_tfidf_vectorizer.vocabulary_.items())[:])

# check word index in vocabulary
print(unigram_tfidf_vectorizer.vocabulary_.get('ordered'))
# Out:
# (745, 353)
# 353
# ...

# %%
# fit vocabulary in training documents and transform the training documents into vectors
X_train_vecub = gram12_count_vectorizer.fit_transform(tweets)

# check the content of a document vector
print(X_train_vecub.shape)
#print(X_train_vecub[0].toarray())

# check the size of the constructed vocabulary
print(len(gram12_count_vectorizer.vocabulary_))

# print out the first 10 items in the vocabulary
print(list(gram12_count_vectorizer.vocabulary_.items())[:])

# check word index in vocabulary
print(gram12_count_vectorizer.vocabulary_.get('ordered'))
# Out:
# (745, 444)
# 444
# ...
